# %% [markdown]
# <a href="https://colab.research.google.com/github/debby14/uas-stki/blob/main/tugas_uas_stki.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import string 
import re

from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords

# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 209 kB 6.3 MB/s
# ...

# %%
web = requests.get('https://jakarta.tribunnews.com/').text
soup = BeautifulSoup(web)
for s in soup(['script','style']):
    s.decompose()
teks = ''.join(soup.stripped_strings)
print(teks)
# Out:
# Tribunjakarta.com - Berita Terkini JakartaTribunnews.comSelasa, 29 November 2022CariNetworkTribunnews.comTribunnewsWiki.comTribunStyle.comTribunTravel.comTribunWow.comTribunNewsmaker.comTribun-Video.comTribunJualBeli.comTribunHealth.comTribunTrends.comTribunJakarta.comWartaKotalive.comTribunBekasi.comTribunBanten.comTribunTangerang.comTribunnewsDepok.comTribunJabar.idTribunnewsBogor.comTribunCirebon.comTribunJateng.comTribunSolo.comTribunBanyumas.comTribunMuria.comTribun-Pantura.comTribunJogja.comTribunJatim.comSurya.co.idSuryaMalang.comTribunMataraman.comTribunMadura.comTribun-Bali.comSerambiNews.comProhaba.coTribunGayo.comTribunnewsSultra.comTribun-Medan.comSripoku.comBangkaPos.comTribunBatam.idPosBelitung.coBabelNews.idTribunPadang.comTribunBengkulu.comTribunPekanbaru.comTribunJambi.comTribunSumsel.comTribunLampung.co.idPos-Kupang.comTribunFlores.comBanjarmasinPost.co.idTribunKaltim.coTribunKalteng.comTribunKaltara.comTribunManado.co.idTribunGorontalo.comTribun-Sulbar.comTribunPon
# ...

# %%
teks = teks.lower()
teks = re.sub("\d+","",teks)
teks = teks.translate(str.maketrans("","",string.punctuation))
teks = teks.strip()
factory = StemmerFactory()
stemmer = factory.create_stemmer()
output = stemmer.stem(teks)
print(output)
# Out:
# tribunjakartacom berita kini jakartatribunnewscomselasa november ... epapergramediacomgramedia digitalikuti kamiyoutubefacebookinstagramtwittergoogle newstiktokhiprofilekirim imageslogoutloginbelum punya akunmendaftarhomenewsmata lokal memilihpemilu legislatifpilprespilkadajakartabodetabekpropertileisuretransportasieventlainnyapemilusportsuper balllifestyleotomotiftechnokesehatantribunjakartawikicomindeks beritatravelakomodasikulinerdestinasishoppingticketingtribunjakartatravelcomjadwal hasilpiala dunia hari ini wibecuadorsenegalhari ini wibbelandaqatarbesok wibiranamerika serikatbesok wibwalesinggrisbesok wibtunisiaprancisbesok wibaustraliadenmark december wibpolandiaargentina december wibsaudi arabiamexicoindeks beritaindeks azpilpres masih di bawah ganjar upaya anies kerek elektabilitas belum ada hasil meski bulan safari politikgempa di cianjurkorban tewas gempa cianjur tambah jadi orang jenazah temu di desa cijedilramalan zodiakbaperan zodiak yang kenal mudah jatuh cinta aries di
# ...

# %%
tokens = [t for t in output.split()]
print(tokens)
# Out:
# ['tribunjakartacom', 'berita', 'kini', 'jakartatribunnewscomselasa', 'november', '...', 'epapergramediacomgramedia', 'digitalikuti', 'kamiyoutubefacebookinstagramtwittergoogle', 'newstiktokhiprofilekirim', 'imageslogoutloginbelum', 'punya', 'akunmendaftarhomenewsmata', 'lokal', 'memilihpemilu', 'legislatifpilprespilkadajakartabodetabekpropertileisuretransportasieventlainnyapemilusportsuper', 'balllifestyleotomotiftechnokesehatantribunjakartawikicomindeks', 'beritatravelakomodasikulinerdestinasishoppingticketingtribunjakartatravelcomjadwal', 'hasilpiala', 'dunia', 'hari', 'ini', 'wibecuadorsenegalhari', 'ini', 'wibbelandaqatarbesok', 'wibiranamerika', 'serikatbesok', 'wibwalesinggrisbesok', 'wibtunisiaprancisbesok', 'wibaustraliadenmark', 'december', 'wibpolandiaargentina', 'december', 'wibsaudi', 'arabiamexicoindeks', 'beritaindeks', 'azpilpres', 'masih', 'di', 'bawah', 'ganjar', 'upaya', 'anies', 'kerek', 'elektabilitas', 'belum', 'ada', 'hasil', 'meski', 'bulan', 'safari', 'politik
# ...

# %%
nltk.download()
clean_tokens = tokens[:]
for token in tokens:
  if token in stopwords.words('indonesian'):
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)
for key,val in freq.items():
  print(str(key) + ":" + str(val))

freq.plot(30)
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Command 'all' unrecognized
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
#
# Download which package (l=list; x=cancel)?
#     Error loading d: Package 'd' not found in index
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
#
# Download which package (l=list; x=cancel)?
#
# ---------------------------------------------------------------------------
# ...
